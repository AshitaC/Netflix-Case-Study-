# %% [markdown]
# <a href="https://colab.research.google.com/github/AshitaC/Netflix-Case-Study-/blob/main/Netflix_CaseStudy_DataExploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Netflix Case: Business Problem
#
# Analyze the data and generate insights that could help Netflix in deciding which type of shows/movies to produce and how they can grow the business in different countries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('netflix.csv')
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# Dataset contains 8807 records and 12 features for movies and TV shows released between 1925 to 2021

# %%
df.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1767
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# There are null values in 5 columns namely - director, cast, country, date_added, rating

# %%
df['director']=df['director'].fillna('NoDataAvailable')
df['country']=df['country'].fillna(df['country'].mode()[0])
df['cast'] = df['cast'].fillna('NoDataAvailable')
df['date_added'] = df['date_added'].fillna(df['date_added'].mode()[0])
df['rating'] = df['rating'].fillna(df['rating'].mode()[0])
df['duration'] = df['duration'].fillna(df['duration'].mode()[0])
print(df.isnull().sum())
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# Since we are not working with text data here , we will drop the 'description' column
df.drop('description',axis=1,inplace=True)

# %%
# We dont need show_id so dropping it
df.drop('show_id',axis=1,inplace=True)

# %%
#converting date_added to datetime and extracting info from it
df['date_added']=pd.to_datetime(df['date_added'])
df['year']=df['date_added'].dt.year
df['month']=df['date_added'].dt.month
df['month_name']=df['date_added'].dt.month_name()
df['day_name']=df['date_added'].dt.day_name()
df.head(3)
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water  NoDataAvailable
# 2  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                    NoDataAvailable  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  year  month month_name  \
# 0                                      Documentaries  2021      9  September
# 1    International TV Shows, TV Dramas, TV Mysteries  2021      9  September
# 2  Crime TV Shows, International TV Shows, TV Act...  2021      9  September
#
#    day_name
# 0  Saturday
# 1    Friday
# 2    Friday

# %%
df['rating'].value_counts()
# Out:
# TV-MA       3211
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %% [markdown]
# Some of the rating columns have duration values so drop these 3 rows

# %%
df[df['rating'].str.contains('min')]
# Out:
#        type                                 title    director        cast  \
# 5541  Movie                       Louis C.K. 2017  Louis C.K.  Louis C.K.
# 5794  Movie                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
# 5813  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#             country date_added  release_year  rating  duration listed_in  \
# 5541  United States 2017-04-04          2017  74 min  1 Season    Movies
# 5794  United States 2016-09-16          2010  84 min  1 Season    Movies
# 5813  United States 2016-08-15          2015  66 min  1 Season    Movies
#
#       year  month month_name day_name
# 5541  2017      4      April  Tuesday
# 5794  2016      9  September   Friday
# 5813  2016      8     August   Monday

# %%
df.drop(5541, axis=0,inplace=True) 
df.drop(5794, axis=0,inplace=True) 
df.drop(5813, axis=0,inplace=True)

# %%
df['rating'].value_counts()
# Out:
# TV-MA       3211
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %%
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}
df["ratings_ages"]=df["rating"].replace(ratings_ages)
df['ratings_ages']
# Out:
# 0            Teens
# 1           Adults
# 2           Adults
# 3           Adults
# 4           Adults
#            ...
# 8802        Adults
# 8803    Older Kids
# 8804        Adults
# 8805    Older Kids
# 8806         Teens
# Name: ratings_ages, Length: 8804, dtype: object

# %%
df['duration']=df['duration'].apply(lambda x: str(x).split(' ')[0])
df['duration']
# Out:
# 0        90
# 1         2
# 2         1
# 3         1
# 4         2
#        ...
# 8802    158
# 8803      2
# 8804     88
# 8805     88
# 8806    111
# Name: duration, Length: 8804, dtype: object

# %%
# duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
df.head(20)
# Out:
#        type                                              title  \
# 0     Movie                               Dick Johnson Is Dead
# 1   TV Show                                      Blood & Water
# 2   TV Show                                          Ganglands
# 3   TV Show                              Jailbirds New Orleans
# 4   TV Show                                       Kota Factory
# 5   TV Show                                      Midnight Mass
# 6     Movie                   My Little Pony: A New Generation
# 7     Movie                                            Sankofa
# 8   TV Show                      The Great British Baking Show
# 9     Movie                                       The Starling
# 10  TV Show                Vendetta: Truth, Lies and The Mafia
# 11  TV Show                                   Bangkok Breaking
# 12    Movie                                       Je Suis Karl
# 13    Movie                   Confessions of an Invisible Girl
# 14  TV Show                    Crime Stories: India Detectives
# 15  TV Show                                  Dear White People
# 16    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17  TV Show                                    Falsa identidad
# 18    Movie                                          Intrusion
# 19  TV Show                                             Jaguar
#
#                                          director  \
# 0                                 Kirsten Johnson
# 1                                 NoDataAvailable
# 2                                 Julien Leclercq
# 3                                 NoDataAvailable
# 4                                 NoDataAvailable
# 5                                   Mike Flanagan
# 6                   Robert Cullen, José Luis Ucha
# 7                                    Haile Gerima
# 8                                 Andy Devonshire
# 9                                  Theodore Melfi
# 10                                NoDataAvailable
# 11                              Kongkiat Komesiri
# 12                            Christian Schwochow
# 13                                  Bruno Garotti
# 14                                NoDataAvailable
# 15                                NoDataAvailable
# 16  Pedro de Echave García, Pablo Azorín Williams
# 17                                NoDataAvailable
# 18                                     Adam Salky
# 19                                NoDataAvailable
#
#                                                  cast  \
# 0                                     NoDataAvailable
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2   Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                     NoDataAvailable
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 10                                    NoDataAvailable
# 11  Sukollawat Kanarot, Sushar Manaying, Pavarit M...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 14                                    NoDataAvailable
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...
# 16                                    NoDataAvailable
# 17  Luis Ernesto Franco, Camila Sodi, Sergio Goyri...
# 18  Freida Pinto, Logan Marshall-Green, Robert Joh...
# 19  Blanca Suárez, Iván Marcos, Óscar Casas, Adriá...
#
#                                               country date_added  \
# 0                                       United States 2021-09-25
# 1                                        South Africa 2021-09-24
# 2                                       United States 2021-09-24
# 3                                       United States 2021-09-24
# 4                                               India 2021-09-24
# 5                                       United States 2021-09-24
# 6                                       United States 2021-09-24
# 7   United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 8                                      United Kingdom 2021-09-24
# 9                                       United States 2021-09-24
# 10                                      United States 2021-09-24
# 11                                      United States 2021-09-23
# 12                            Germany, Czech Republic 2021-09-23
# 13                                      United States 2021-09-22
# 14                                      United States 2021-09-22
# 15                                      United States 2021-09-22
# 16                                      United States 2021-09-22
# 17                                             Mexico 2021-09-22
# 18                                      United States 2021-09-22
# 19                                      United States 2021-09-22
#
#     release_year rating duration  \
# 0           2020  PG-13       90
# 1           2021  TV-MA        2
# 2           2021  TV-MA        1
# 3           2021  TV-MA        1
# 4           2021  TV-MA        2
# 5           2021  TV-MA        1
# 6           2021     PG       91
# 7           1993  TV-MA      125
# 8           2021  TV-14        9
# 9           2021  PG-13      104
# 10          2021  TV-MA        1
# 11          2021  TV-MA        1
# 12          2021  TV-MA      127
# 13          2021  TV-PG       91
# 14          2021  TV-MA        1
# 15          2021  TV-MA        4
# 16          2020  TV-MA       67
# 17          2020  TV-MA        2
# 18          2021  TV-14       94
# 19          2021  TV-MA        1
#
#                                             listed_in  year  month month_name  \
# 0                                       Documentaries  2021      9  September
# 1     International TV Shows, TV Dramas, TV Mysteries  2021      9  September
# 2   Crime TV Shows, International TV Shows, TV Act...  2021      9  September
# 3                              Docuseries, Reality TV  2021      9  September
# 4   International TV Shows, Romantic TV Shows, TV ...  2021      9  September
# 5                  TV Dramas, TV Horror, TV Mysteries  2021      9  September
# 6                            Children & Family Movies  2021      9  September
# 7    Dramas, Independent Movies, International Movies  2021      9  September
# 8                        British TV Shows, Reality TV  2021      9  September
# 9                                    Comedies, Dramas  2021      9  September
# 10  Crime TV Shows, Docuseries, International TV S...  2021      9  September
# 11  Crime TV Shows, International TV Shows, TV Act...  2021      9  September
# 12                       Dramas, International Movies  2021      9  September
# 13                 Children & Family Movies, Comedies  2021      9  September
# 14       British TV Shows, Crime TV Shows, Docuseries  2021      9  September
# 15                             TV Comedies, TV Dramas  2021      9  September
# 16                Documentaries, International Movies  2021      9  September
# 17  Crime TV Shows, Spanish-Language TV Shows, TV ...  2021      9  September
# 18                                          Thrillers  2021      9  September
# 19  International TV Shows, Spanish-Language TV Sh...  2021      9  September
#
#      day_name ratings_ages
# 0    Saturday        Teens
# 1      Friday       Adults
# 2      Friday       Adults
# 3      Friday       Adults
# 4      Friday       Adults
# 5      Friday       Adults
# 6      Friday   Older Kids
# 7      Friday       Adults
# 8      Friday        Teens
# 9      Friday        Teens
# 10     Friday       Adults
# 11   Thursday       Adults
# 12   Thursday       Adults
# 13  Wednesday   Older Kids
# 14  Wednesday       Adults
# 15  Wednesday       Adults
# 16  Wednesday       Adults
# 17  Wednesday       Adults
# 18  Wednesday        Teens
# 19  Wednesday       Adults

# %% [markdown]
# Unnesting the columns of
#
# - cast
# -director
# -country
# -listed_in

# %%
# unnesting 'cast' columnn to make a new dataframe of indiviadual cast, indexed by title
constraint=df['cast'].apply(lambda x:str(x).split(', ')).tolist()
df_new=pd.DataFrame(constraint,index=df['title'])
df_new=df_new.stack()
df_new=pd.DataFrame(df_new)
df_new.reset_index(inplace=True)
df_new=df_new[['title',0]]
df_new.columns=['title','cast']
filtered_cast = pd.DataFrame()
filtered_cast=df_new
filtered_cast.head(5)
# Out:
#                   title             cast
# 0  Dick Johnson Is Dead  NoDataAvailable
# 1         Blood & Water       Ama Qamata
# 2         Blood & Water      Khosi Ngema
# 3         Blood & Water    Gail Mabalane
# 4         Blood & Water   Thabang Molaba

# %%
# unnesting 'director' columnn to make a new dataframe of individual director, indexed by title
constraint=df['director'].apply(lambda x:str(x).split(', ')).tolist()
df_new=pd.DataFrame(constraint,index=df['title'])
df_new=df_new.stack()
df_new=pd.DataFrame(df_new)
df_new.reset_index(inplace=True)
df_new=df_new[['title',0]]
df_new.columns=['title','director']
filtered_director = pd.DataFrame()
filtered_director=df_new
filtered_director.head(5)
# Out:
#                    title         director
# 0   Dick Johnson Is Dead  Kirsten Johnson
# 1          Blood & Water  NoDataAvailable
# 2              Ganglands  Julien Leclercq
# 3  Jailbirds New Orleans  NoDataAvailable
# 4           Kota Factory  NoDataAvailable

# %%
# unnesting 'country' columnn to make a new dataframe of individual country, indexed by title
constraint=df['country'].apply(lambda x:str(x).split(', ')).tolist()
df_new=pd.DataFrame(constraint,index=df['title'])
df_new=df_new.stack()
df_new=pd.DataFrame(df_new)
df_new.reset_index(inplace=True)
df_new=df_new[['title',0]]
df_new.columns=['title','country']
filtered_country = pd.DataFrame()
filtered_country=df_new
filtered_country.head(5)
# Out:
#                    title        country
# 0   Dick Johnson Is Dead  United States
# 1          Blood & Water   South Africa
# 2              Ganglands  United States
# 3  Jailbirds New Orleans  United States
# 4           Kota Factory          India

# %%
# unnesting 'listed_in' columnn to make a new dataframe of individual country, indexed by title
constraint=df['listed_in'].apply(lambda x:str(x).split(', ')).tolist()
df_new=pd.DataFrame(constraint,index=df['title'])
df_new=df_new.stack()
df_new=pd.DataFrame(df_new)
df_new.reset_index(inplace=True)
df_new=df_new[['title',0]]
df_new.columns=['title','listed_in']
filtered_listed_in = pd.DataFrame()
filtered_listed_in=df_new
filtered_listed_in.head(5)
# Out:
#                   title               listed_in
# 0  Dick Johnson Is Dead           Documentaries
# 1         Blood & Water  International TV Shows
# 2         Blood & Water               TV Dramas
# 3         Blood & Water            TV Mysteries
# 4             Ganglands          Crime TV Shows

# %%
dff=filtered_cast.merge(filtered_director,on='title',how='inner')
dff=dff.merge(filtered_country,on='title',how='inner')
dff=dff.merge(filtered_listed_in,on='title',how='inner')
dff.head(5)
# Out:
#                   title             cast         director        country  \
# 0  Dick Johnson Is Dead  NoDataAvailable  Kirsten Johnson  United States
# 1         Blood & Water       Ama Qamata  NoDataAvailable   South Africa
# 2         Blood & Water       Ama Qamata  NoDataAvailable   South Africa
# 3         Blood & Water       Ama Qamata  NoDataAvailable   South Africa
# 4         Blood & Water      Khosi Ngema  NoDataAvailable   South Africa
#
#                 listed_in
# 0           Documentaries
# 1  International TV Shows
# 2               TV Dramas
# 3            TV Mysteries
# 4  International TV Shows

# %%
df_new=df[['type','title','year','month','release_year','ratings_ages','duration']]
df_new.head(5)
# Out:
#       type                  title  year  month  release_year ratings_ages  \
# 0    Movie   Dick Johnson Is Dead  2021      9          2020        Teens
# 1  TV Show          Blood & Water  2021      9          2021       Adults
# 2  TV Show              Ganglands  2021      9          2021       Adults
# 3  TV Show  Jailbirds New Orleans  2021      9          2021       Adults
# 4  TV Show           Kota Factory  2021      9          2021       Adults
#
#   duration
# 0       90
# 1        2
# 2        1
# 3        1
# 4        2

# %%
dff=dff.merge(df_new,on='title',how='inner')
dff.head(5)
# Out:
#                   title             cast         director        country  \
# 0  Dick Johnson Is Dead  NoDataAvailable  Kirsten Johnson  United States
# 1         Blood & Water       Ama Qamata  NoDataAvailable   South Africa
# 2         Blood & Water       Ama Qamata  NoDataAvailable   South Africa
# 3         Blood & Water       Ama Qamata  NoDataAvailable   South Africa
# 4         Blood & Water      Khosi Ngema  NoDataAvailable   South Africa
#
#                 listed_in     type  year  month  release_year ratings_ages  \
# 0           Documentaries    Movie  2021      9          2020        Teens
# 1  International TV Shows  TV Show  2021      9          2021       Adults
# 2               TV Dramas  TV Show  2021      9          2021       Adults
# 3            TV Mysteries  TV Show  2021      9          2021       Adults
# 4  International TV Shows  TV Show  2021      9          2021       Adults
#
#   duration
# 0       90
# 1        2
# 2        2
# 3        2
# 4        2

# %% [markdown]
# This is our final clean unnested data

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Distribution of content type

# %%
df['type'].value_counts(normalize=True)
# Out:
# Movie      0.696047
# TV Show    0.303953
# Name: type, dtype: float64

# %%
sns.countplot(x='type', data=df)
plt.show()

# %% [markdown]
# It is clear that about 69.6% content was Movies and 30.3% content was TV-shows.
#
# ---

# %% [markdown]
# # Content added over years

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='year',data=df,color='green')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# Not much content was uploaded on Netflix upto 2014. Number of movies and tv shows began to rise from 2015 and peaked in 2019 and started dipping from 2020 onwards.

# %%
content=df.groupby(['type','year'])['release_year'].count().reset_index()
content.head(5)
# Out:
#     type  year  release_year
# 0  Movie  2008             1
# 1  Movie  2009             2
# 2  Movie  2010             1
# 3  Movie  2011            13
# 4  Movie  2012             3

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='year',y='release_year',data=content,hue='type')
plt.show()

# %% [markdown]
# The above trend shows that not much content was added upto 2014, however between 2015-2019 the content increased and peaked in 2019 after that started to decline again. Most of the content was movies all throughout.

# %% [markdown]
# # Countries with highest number of uploads

# %%
top10=dff[['country']].value_counts().sort_values(ascending=False).head(10)
top10=top10.to_frame()
top10.reset_index(inplace=True)
top10.columns=['country','num_content']
top10
# Out:
#           country  num_content
# 0   United States        71243
# 1           India        22814
# 2  United Kingdom        12945
# 3           Japan         8679
# 4          France         8254
# 5          Canada         7915
# 6           Spain         5315
# 7     South Korea         5043
# 8         Germany         4383
# 9          Mexico         3941

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='country',x='num_content',data=top10,color='orange')
plt.show()

# %% [markdown]
# Clearly, US uploaded most number of content with India being second and UK being the third.

# %% [markdown]
# #Monthly and weekly trend

# %%
monthly=df[['month_name','month']].value_counts().reset_index()
monthly.rename(columns={0:"number_contents"}, inplace=True)
monthly=monthly.sort_values('month')
monthly
# Out:
#    month_name  month  number_contents
# 6     January      1              748
# 11   February      2              563
# 7       March      3              742
# 3       April      4              763
# 10        May      5              632
# 8        June      6              728
# 0        July      7              827
# 5      August      8              754
# 2   September      9              769
# 4     October     10              760
# 9    November     11              705
# 1    December     12              813

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x='month_name',y='number_contents',data=monthly)
plt.ylim(500,850)
plt.show()

# %% [markdown]
# Most of the content was added in second half of the year

# %%
weekly=df[['day_name']].value_counts().reset_index()
weekly.rename(columns={0:"number_contents"}, inplace=True)
weekly=weekly.sort_values('day_name')
weekly
# Out:
#     day_name  number_contents
# 0     Friday             2497
# 4     Monday              850
# 5   Saturday              816
# 6     Sunday              751
# 1   Thursday             1396
# 3    Tuesday             1196
# 2  Wednesday             1298

# %%
# ordering weekdays
weekly['day_name']=weekly['day_name'].astype('category')
weekly['day_name']=weekly['day_name'].cat.reorder_categories(['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
weekly
# Out:
#     day_name  number_contents
# 0     Friday             2497
# 4     Monday              850
# 5   Saturday              816
# 6     Sunday              751
# 1   Thursday             1396
# 3    Tuesday             1196
# 2  Wednesday             1298

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='day_name',y='number_contents',data=weekly,color='red')
#plt.ylim(500,850)
plt.show()

# %% [markdown]
# The number of uploaded content is significantly higher on Friday

# %% [markdown]
# # Content Duration

# %%
movie=df[['title','type','duration']][df['type']=='Movie']
movie.head(5)
# Out:
#                                title   type duration
# 0               Dick Johnson Is Dead  Movie       90
# 6   My Little Pony: A New Generation  Movie       91
# 7                            Sankofa  Movie      125
# 9                       The Starling  Movie      104
# 12                      Je Suis Karl  Movie      127

# %%
sns.distplot(movie['duration'])
plt.show()

# %% [markdown]
# Most of the movies have duration between 70-120 minutes

# %%
show=df[['title','type','duration']][df['type']=='TV Show']
show.head(5)
# Out:
#                    title     type duration
# 1          Blood & Water  TV Show        2
# 2              Ganglands  TV Show        1
# 3  Jailbirds New Orleans  TV Show        1
# 4           Kota Factory  TV Show        2
# 5          Midnight Mass  TV Show        1

# %%
shows=show['duration'].value_counts().reset_index()
shows.rename(columns={'index':'season','duration':'num_content'},inplace=True)
shows.head(5)
# Out:
#   season  num_content
# 0      1         1793
# 1      2          425
# 2      3          199
# 3      4           95
# 4      5           65

# %%
sns.barplot(x='season',y='num_content',data=shows,color='blue')
plt.show()

# %% [markdown]
# Most of the TV shows have 1 season.

# %% [markdown]
# # Ratings of contents

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='rating',hue='type')
plt.show()

# %% [markdown]
# Most of the content in both Movies and TV shows is rated TV-MA, more suitable for adults rather than kids. Second highest content is rated for 14 years and above.

# %%
ratings=df['ratings_ages'].value_counts().reset_index()
ratings
# Out:
#         index  ratings_ages
# 0      Adults          4096
# 1       Teens          2650
# 2  Older Kids          1490
# 3        Kids           568

# %%
plt.pie(ratings['ratings_ages'],labels=ratings['index'])
plt.show()

# %% [markdown]
# # Top Director

# %%
director=filtered_director.groupby(['director'])['title'].count().sort_values(ascending=False).reset_index().head(11)
director.rename(columns={'title':'num_content'},inplace=True)
director
# Out:
#                director  num_content
# 0       NoDataAvailable         2634
# 1         Rajiv Chilaka           22
# 2             Jan Suter           21
# 3           Raúl Campos           19
# 4           Suhas Kadav           16
# 5          Marcus Raboy           16
# 6             Jay Karas           15
# 7   Cathy Garcia-Molina           13
# 8           Jay Chapman           12
# 9       Youssef Chahine           12
# 10      Martin Scorsese           12

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='director',x='num_content',data=director[1:6],color='red')
plt.show()

# %% [markdown]
# # Top actor

# %%
actor=filtered_cast.groupby(['cast'])['title'].count().sort_values(ascending=False).reset_index().head(11)
actor.rename(columns={'cast':'actor','title':'num_content'},inplace=True)
actor
# Out:
#                actor  num_content
# 0    NoDataAvailable          825
# 1        Anupam Kher           43
# 2     Shah Rukh Khan           35
# 3      Julie Tejwani           33
# 4   Naseeruddin Shah           32
# 5   Takahiro Sakurai           32
# 6       Rupa Bhimani           31
# 7            Om Puri           30
# 8       Akshay Kumar           30
# 9          Yuki Kaji           29
# 10  Amitabh Bachchan           28

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='actor',x='num_content',data=actor[1:6],color='blue')
plt.show()

# %% [markdown]
# # Top Genres

# %%
len(dff['listed_in'].value_counts().reset_index())
# Out:
# 42

# %% [markdown]
# 42 genres available

# %%
genres=dff['listed_in'].value_counts().reset_index().head(10)
genres.rename(columns={'index':'genres','listed_in':'num_content'},inplace=True)
genres
# Out:
#                      genres  num_content
# 0                    Dramas        29775
# 1      International Movies        28211
# 2                  Comedies        20829
# 3    International TV Shows        12845
# 4        Action & Adventure        12216
# 5        Independent Movies         9834
# 6  Children & Family Movies         9771
# 7                 TV Dramas         8942
# 8                 Thrillers         7107
# 9           Romantic Movies         6412

# %%
plt.figure(figsize=(10,5))
sns.barplot(y='genres',x='num_content',data=genres,color='green')
plt.show()

# %% [markdown]
# Drama was the most preferred genre

# %% [markdown]
# #Findings-
#
# - Most of the content released was movies 66% and only 33% were TV shows.
#
# - USA produced most content followed by India.
#
# - Max content was uploaded in 2019.
#
# - Friday is the day of maximum uploaded content.
#
# - Second half of the year sees more content upload.
#
# - 42 genres of movies and shows are available, most popular being Dramas.
#
# - Most movies have duration 70-120 mins.
#
# - Most TV shows have 1 season.
#
# - Most of the content is rated for adults followed by teens and very little for kids.
